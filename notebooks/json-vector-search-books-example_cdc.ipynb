# %% [markdown]
# <img src = "https://github.com/VeryFatBoy/notebooks/blob/main/common/images/img_github_singlestore-jupyter_featured_2.png?raw=true">

# %% [markdown]
# <div id="singlestore-header" style="display: flex; background-color: rgba(235, 249, 245, 0.25); padding: 5px;">
#     <div id="icon-image" style="width: 90px; height: 90px;">
#         <img width="100%" height="100%" src="https://raw.githubusercontent.com/singlestore-labs/spaces-notebooks/master/common/images/header-icons/browser.png" />
#     </div>
#     <div id="text" style="padding: 5px; margin-left: 10px;">
#         <div id="badge" style="display: inline-block; background-color: rgba(0, 0, 0, 0.15); border-radius: 4px; padding: 4px 8px; align-items: center; margin-top: 6px; margin-bottom: -2px; font-size: 80%">SingleStore Notebooks</div>
#         <h1 style="font-weight: 500; margin: 8px 0 0 4px;">JSON Vector Search Books Example</h1>
#     </div>
# </div>

# %% [markdown]
# Adapted from a [notebook](https://github.com/singlestore-labs/devrel-notebook-examples/blob/main/json-vector-search-books-example/json-vector-search-books-example.ipynb) on GitHub by [Yaroslav Demenskyi](https://github.com/demenskyi).

# %% [markdown]
# ## 1. Install and import packages

# %%
# !pip cache purge --quiet

# %%
# !pip install openai==0.28 numpy pymongo --quiet

# %%
import openai
import json
import struct
import requests
from bson import ObjectId
from pymongo import MongoClient
from typing import TypedDict, Optional

# %% [markdown]
# ## 2. Set constants

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
# Out:
# OpenAI API Key: ········

# %%
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
DB_NAME = "bookstore"
SOURCE_COLLECTION_NAME = "books"
EMBEDDINGS_COLLECTION_NAME = "books_with_embedding"
BOOK_EMBEDDINGS_NUMBER = 50

# %% [markdown]
# ## 3.  Set variables

# %%
openai.api_key = OPENAI_API_KEY
client = MongoClient(connection_url_kai)
db = client.get_database(DB_NAME)
sourceCollection = db[SOURCE_COLLECTION_NAME]
embeddingsCollection = db[EMBEDDINGS_COLLECTION_NAME]

# %% [markdown]
# ## 4. Set helper classes

# %%
class Book(TypedDict):
    title: str
    subjects: list[str]
    description: str
    price: float
    type: str
    createdAt: str
    updatedAt: str


class BookWithEmbedding(Book):
    embedding: str


class JSONEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, ObjectId):
            return str(o)
        return super().default(o)

# %% [markdown]
# ## 5. Define helper functions

# %% [markdown]
# Function to create an embedding using the OpenAI Embedding API

# %%
create_embedding_retries = 0

def create_embedding(data: str | dict) -> list[float]:
    global create_embedding_retries

    if type(data) is dict:
        data = json.dumps(data, cls=JSONEncoder)

    try:
        data = data.replace("\n", " ")
        response = openai.Embedding.create(input=data, model="text-embedding-ada-002")
        create_embedding_retries = 0
        return response["data"][0]["embedding"]
    except Exception as e:
        if create_embedding_retries < 5:
            print("An error occurred while creating the embedding. Retrying...", "\n", e)
            create_embedding_retries = create_embedding_retries + 1
            return create_embedding(data)
        else:
            print("Maximum retries reached.", "\n", e)

# %% [markdown]
# Function to convert data into binary data

# %%
def data_to_binary(data: list[float]):
    format_string = "f" * len(data)
    return struct.pack(format_string, *data)

# %% [markdown]
# Function to validate a collection before the loading

# %%
def validate_collection(name: str):
    if not name in db.list_collection_names():
        return False

    if db[name].estimated_document_count() == 0:
        return False

    return True

# %% [markdown]
# Function to retrieve metadata from the database to check if the value of `last_book_embeddings_number` has changed to start the load step.

# %%
def get_meta():
    return db["meta"].find_one()

# %% [markdown]
# Function to update the meta data

# %%
def update_meta(book_embeddings_number: int):
    db["meta"].update_one({"_id": get_meta()["_id"]}, {
        "$set": {"last_book_embeddings_number": book_embeddings_number}
    })

# %% [markdown]
# Function for retrieving books from the source collection to be used to create embeddings

# %%
def get_books(limit: Optional[int] = None) -> list[Book]:
    query = sourceCollection.find()

    if type(limit) is int:
        query.limit(limit)

    return list(query)

# %% [markdown]
# Function to set source collection data

# %%
def load_source():

    def insert_meta():
        db["meta"].insert_one({"last_book_embeddings_number": 0})

    if validate_collection(SOURCE_COLLECTION_NAME):
        print("Source loading")
        insert_meta()

# %% [markdown]
# Function to insert/drop a collection with embeddings that will be used to search with $dotProduct. If the value of `BOOK_EMBEDDINGS_NUMBER` is changed, the collection is reset.

# %%
def load_embeddings():
    is_same_embeddings_number = get_meta()["last_book_embeddings_number"] == BOOK_EMBEDDINGS_NUMBER

    def reset_collection():
        global embeddingsCollection
        embeddingsCollection.drop()
        db.create_collection(EMBEDDINGS_COLLECTION_NAME, columns=[{"id": "embedding", "type": "LONGBLOB NOT NULL"}])
        embeddingsCollection = db[EMBEDDINGS_COLLECTION_NAME]

    def create_embeddings(books: list[Book]) -> list[BookWithEmbedding]:
        embeddings = []

        for book in books:
            embedding = create_embedding(book)
            embedding_binary = data_to_binary(embedding)
            embeddings.append({**book, "embedding": embedding_binary})

        return embeddings

    def insert_embeddings(embeddings: list[BookWithEmbedding]):
        embeddingsCollection.insert_many(embeddings)

    if not validate_collection(EMBEDDINGS_COLLECTION_NAME) or not is_same_embeddings_number:
        print("Embeddings loading")
        reset_collection()
        books = get_books(BOOK_EMBEDDINGS_NUMBER)
        embeddings = create_embeddings(books)
        insert_embeddings(embeddings)
        update_meta(BOOK_EMBEDDINGS_NUMBER)

# %% [markdown]
# Function to search for books with a string query and $dotProduct

# %%
def search(query: str):
    print("Searching:", query)

    query_embedding = create_embedding(query)
    query_binary = data_to_binary(query_embedding)
    query_result = embeddingsCollection.aggregate([
        {"$addFields": {"dot": {"$dotProduct": ["$embedding", query_binary]}}},
        {"$project": {"embedding": 0}},
        {"$sort": {"dot": -1}},
        {"$limit": 5},
    ])

    result = list(query_result)

    print(json.dumps(result, cls=JSONEncoder, indent=4))

    return result

# %% [markdown]
# ## 6. Prepare and load collections

# %%
load_source()
load_embeddings()
# Out:
# Source loading
# Embeddings loading

# %% [markdown]
# ## 7. Use search

# %%
search("Recommend books about the horror genre")
# Out:
# Searching: Recommend books about the horror genre
# [
#     {
#         "title": "The doll that waved goodbye and other scary tales",
#         "subjects": [
#             "American Horror tales",
#             "Children's stories, American"
#         ],
#         "description": "Livia wears a small porcelain hand around her neck, all that is left of a doll that once belonged to her grandmother, but on the first night at summer camp the hand comes alive and terrifies an envious cabinmate -- and there are plenty of chills in five other stories in this collection.",
#         "price": 69.4,
#         "type": "paperback",
#         "createdAt": "2020-06-30T06:08:56.610478",
#         "updatedAt": "2020-06-30T06:08:56.610478",
#         "_id": "64e3d055c330effc84b20af7",
#         "dot": 0.7928498387336731
#     },
#     {
#         "title": "The art of eating through the zombie apocalypse",
#         "subjects": [
#             "Survival",
#             "Cooking",
#             "Humor",
#             "Zombies",
#             "Humor, general",
#             "COOKING / Courses & Dishes / General",
#             "COOKING / Methods / General",
#             "CRAFTS & HOBBIES / Reference",
#             "SOCIAL SCIENCE / Popular Culture"
#         ],
#         "description": "\"The Art of Eating through the Zombie Apocalypse\" is a cookbook and culinary field guide for the busy zombie apocalypse survivor. Included are more than 80 recipes (from \"Overnight of the Living Dead French Toast\" and \"It's Not Easy Growing Greens Salad\" to \"Down & Out Sauerkraut,\" \"Honey & Blackberry Mead,\" and \"Twinkie Trifle\"), scads of gastronomic survival tips, and dozens of diagrams and illustrations that help you scavenge, forage, and improvise your way to an artful post-apocalypse meal. \"The Art of Eating\" is the ideal handbook for efficient food sourcing and inventive meal preparation in the event of an undead uprising. Whether you decide to hole up in your own home or bug out into the wilderness, whether you prefer to scavenge the dregs of society or try your hand at apocalyptic agriculture, and regardless of your level of skill or preparation, \"The Art of Eating\" will help you navigate the wasteland and make the most of what you eat.",
#         "price": 6.82,
#         "type": "paperback",
#         "createdAt": "2019-07-18T17:47:53.109946",
#         "updatedAt": "2020-11-12T23:30:18.842614",
#         "_id": "64e3d055c330effc84b20a09",
#         "dot": 0.7716073393821716
#     },
#     {
#         "title": "Boundary",
#         "subjects": [
#             "Detective and mystery stories",
#             "Teenage girls",
#             "Crimes against",
#             "Fiction",
#             "Investigation",
#             "Young women",
#             "Missing persons",
#             "Murder"
#         ],
#         "description": "In the deep woods of the Maine borderlands, the legend of huntsman Pete Landry is still told around cottage campfires to scare children, a tragic story of love, lust, and madness. During the early summer of 1967, inseparable teenage beauties Sissy Morgan and Zaza Mulligan wander among the vacation cottages in the community of Boundary, drinking and smoking and swearing, attracting the attention of boys and men. First one, and then the other, goes missing, and both are eventually found dead in the forest. Have they been the victims of freak accidents? Or is someone hunting the young women of Boundary? And if there is a hunter, who might be next? The Summer of Love quickly becomes the Summer of Fear, and detective Stan Michaud, already haunted by a case he could not solve, is determined to find out what exactly is happening in Boundary before someone else is found dead.",
#         "price": 65.19,
#         "type": "paperback",
#         "createdAt": "2019-05-23T21:15:42.041733",
#         "updatedAt": "2019-05-23T21:15:42.041733",
#         "_id": "64e3d055c330effc84b208fd",
#         "dot": 0.7560744285583496
#     },
#     {
#         "title": "Valacchia",
#         "subjects": [
#             "Histoires \u00e9rotiques",
#             "Roman fantastique"
#         ],
#         "description": "N'ayez pas peur, bel \u00e9tranger. Vous \u00eates \u00e0 Valacchia, et nous-- savourons tous nos visiteurs. Alors qu'ils voyagent en Roumanie, un accident de voiture oblige un jeune couple \u00e0 trouver refuge dans un manoir d\u00e9cr\u00e9pit dont l'enseigne craquel\u00e9e indique Valacchia. Ils h\u00e9sitent \u00e0 peine avant d'entrer; ainsi d\u00e9bute une folle nuit pour les deux voyageurs, p\u00e9n\u00e9trant sans le savoir dans l'antre de Dame Chrystabella, l'h\u00e9riti\u00e8re de la Reine des Morts. Au fil des heures, ils feront la rencontre de cr\u00e9atures aussi charmantes que terrifiantes, des personnages sensuels qui leur feront vivre des exp\u00e9riences voluptueuses, r\u00e9alisant leurs fantasmes les plus fous. Cette m\u00e9saventure se transformera-t-elle en souvenir de voyage-- inoubliable? Il y avait une pr\u00e9sence \u00e9trange partout autour d'elle, le matelas se pressait dans tous les sens, il y avait ce souffle, ces souffles, \u00e0 peine audibles et pourtant pr\u00e9sents au travers de la brume de sa somnolence, cette \u00e9trange sensation de r\u00eaver.",
#         "price": 15.43,
#         "type": "hardcover",
#         "createdAt": "2021-05-09T08:14:08.790112",
#         "updatedAt": "2021-05-09T08:14:08.790112",
#         "_id": "64e3d055c330effc84b20d8d",
#         "dot": 0.7512387037277222
#     },
#     {
#         "title": "Reckless",
#         "subjects": [
#             "Fiction, fantasy, general",
#             "Fantasy fiction",
#             "Children's fiction",
#             "Fantasy",
#             "Sagen/M\u00e4rchen",
#             "Good and evil",
#             "Juvenile fiction",
#             "Magic",
#             "Fiction"
#         ],
#         "description": "Baba Jagas, Kosaken, Spione und ein Zar, der zu Audienzen in Begleitung eines B\u00e4ren kommt. Diesmal f\u00fchrt die Reise hinter dem Spiegel Fuchs und Jacob weit nach Osten. Auch Will kehrt zur\u00fcck in die Welt, die ihm eine Haut aus Jade gab - auf der Spur der Dunklen Fee. Aber den Zweck der Reise bestimmt ein anderer: der Erlelf hat den Handel nicht vergessen, den Jacob im Labyrinth des Blaubarts mit ihm geschlossen hat, und er lehrt Jacob und Fuchs mehr \u00fcber Erlelfen, als sie je erfahren wollten...",
#         "price": 57.46,
#         "type": "paperback",
#         "createdAt": "2016-05-30T18:41:57.748313",
#         "updatedAt": "2022-07-23T05:47:41.894019",
#         "_id": "64e3d055c330effc84b20757",
#         "dot": 0.7461909055709839
#     }
# ]
# [{'title': 'The doll that waved goodbye and other scary tales',
#   'subjects': ['American Horror tales', "Children's stories, American"],
#   'description': 'Livia wears a small porcelain hand around her neck, all that is left of a doll that once belonged to her grandmother, but on the first night at summer camp the hand comes alive and terrifies an envious cabinmate -- and there are plenty of chills in five other stories in this collection.',
#   'price': 69.4,
#   'type': 'paperback',
#   'createdAt': '2020-06-30T06:08:56.610478',
#   'updatedAt': '2020-06-30T06:08:56.610478',
#   '_id': ObjectId('64e3d055c330effc84b20af7'),
#   'dot': 0.7928498387336731},
#  {'title': 'The art of eating through the zombie apocalypse',
#   'subjects': ['Survival',
#    'Cooking',
#    'Humor',
#    'Zombies',
#    'Humor, general',
#    'COOKING / Courses & Dishes / General',
#    'COOKING / Methods / General',
#    'CRAFTS & HOBBIES / Reference',
#    'SOCIAL SCIENCE / Popular Culture'],
#   'description': '"The Art of Eating through the Zombie Apocalypse" is a cookbook and culinary field guide for the busy zombie apocalypse survivor. Included are more than 80 recipes (from "Overnight of the Living Dead French Toast" and "It\'s Not Easy Growing Greens Salad" to "Down & Out Sauerkraut," "Honey & Blackberry Mead," and "Twinkie Trifle"), scads of gastronomic survival tips, and dozens of diagrams and illustrations that help you scavenge, forage, and improvise your way to an artful post-apocalypse meal. "The Art of Eating" is the ideal handbook for efficient food sourcing and inventive meal preparation in the event of an undead uprising. Whether you decide to hole up in your own home or bug out into the wilderness, whether you prefer to scavenge the dregs of society or try your hand at apocalyptic agriculture, and regardless of your level of skill or preparation, "The Art of Eating" will help you navigate the wasteland and make the most of what you eat.',
#   'price': 6.82,
#   'type': 'paperback',
#   'createdAt': '2019-07-18T17:47:53.109946',
#   'updatedAt': '2020-11-12T23:30:18.842614',
#   '_id': ObjectId('64e3d055c330effc84b20a09'),
#   'dot': 0.7716073393821716},
#  {'title': 'Boundary',
#   'subjects': ['Detective and mystery stories',
#    'Teenage girls',
#    'Crimes against',
#    'Fiction',
#    'Investigation',
#    'Young women',
#    'Missing persons',
#    'Murder'],
#   'description': 'In the deep woods of the Maine borderlands, the legend of huntsman Pete Landry is still told around cottage campfires to scare children, a tragic story of love, lust, and madness. During the early summer of 1967, inseparable teenage beauties Sissy Morgan and Zaza Mulligan wander among the vacation cottages in the community of Boundary, drinking and smoking and swearing, attracting the attention of boys and men. First one, and then the other, goes missing, and both are eventually found dead in the forest. Have they been the victims of freak accidents? Or is someone hunting the young women of Boundary? And if there is a hunter, who might be next? The Summer of Love quickly becomes the Summer of Fear, and detective Stan Michaud, already haunted by a case he could not solve, is determined to find out what exactly is happening in Boundary before someone else is found dead.',
#   'price': 65.19,
#   'type': 'paperback',
#   'createdAt': '2019-05-23T21:15:42.041733',
#   'updatedAt': '2019-05-23T21:15:42.041733',
#   '_id': ObjectId('64e3d055c330effc84b208fd'),
#   'dot': 0.7560744285583496},
#  {'title': 'Valacchia',
#   'subjects': ['Histoires érotiques', 'Roman fantastique'],
#   'description': "N'ayez pas peur, bel étranger. Vous êtes à Valacchia, et nous-- savourons tous nos visiteurs. Alors qu'ils voyagent en Roumanie, un accident de voiture oblige un jeune couple à trouver refuge dans un manoir décrépit dont l'enseigne craquelée indique Valacchia. Ils hésitent à peine avant d'entrer; ainsi débute une folle nuit pour les deux voyageurs, pénétrant sans le savoir dans l'antre de Dame Chrystabella, l'héritière de la Reine des Morts. Au fil des heures, ils feront la rencontre de créatures aussi charmantes que terrifiantes, des personnages sensuels qui leur feront vivre des expériences voluptueuses, réalisant leurs fantasmes les plus fous. Cette mésaventure se transformera-t-elle en souvenir de voyage-- inoubliable? Il y avait une présence étrange partout autour d'elle, le matelas se pressait dans tous les sens, il y avait ce souffle, ces souffles, à peine audibles et pourtant présents au travers de la brume de sa somnolence, cette étrange sensation de rêver.",
#   'price': 15.43,
#   'type': 'hardcover',
#   'createdAt': '2021-05-09T08:14:08.790112',
#   'updatedAt': '2021-05-09T08:14:08.790112',
#   '_id': ObjectId('64e3d055c330effc84b20d8d'),
#   'dot': 0.7512387037277222},
#  {'title': 'Reckless',
#   'subjects': ['Fiction, fantasy, general',
#    'Fantasy fiction',
#    "Children's fiction",
#    'Fantasy',
#    'Sagen/Märchen',
#    'Good and evil',
#    'Juvenile fiction',
#    'Magic',
#    'Fiction'],
#   'description': 'Baba Jagas, Kosaken, Spione und ein Zar, der zu Audienzen in Begleitung eines Bären kommt. Diesmal führt die Reise hinter dem Spiegel Fuchs und Jacob weit nach Osten. Auch Will kehrt zurück in die Welt, die ihm eine Haut aus Jade gab - auf der Spur der Dunklen Fee. Aber den Zweck der Reise bestimmt ein anderer: der Erlelf hat den Handel nicht vergessen, den Jacob im Labyrinth des Blaubarts mit ihm geschlossen hat, und er lehrt Jacob und Fuchs mehr über Erlelfen, als sie je erfahren wollten...',
#   'price': 57.46,
#   'type': 'paperback',
#   'createdAt': '2016-05-30T18:41:57.748313',
#   'updatedAt': '2022-07-23T05:47:41.894019',
#   '_id': ObjectId('64e3d055c330effc84b20757'),
#   'dot': 0.7461909055709839}]
